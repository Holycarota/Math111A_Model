# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv("output.csv")
data
# Out:
#          X     Y  Horizontal_Angle  Vertical_Angle   Velocity  IfLeft
# 0    -33.0   0.0         29.290350       18.699604  32.999961       1
# 1    -33.0   1.0         29.762850       18.609057  32.998116       1
# 2    -33.0   2.0         30.249382       18.078100  32.998930       1
# 3    -33.0   3.0         36.441561       19.085116  32.999726       0
# 4    -33.0   4.0         31.266814       17.567108  32.999513       1
# 5    -33.0   5.0         31.798913       17.603450  32.999669       1
# 6    -33.0   6.0         32.347443       17.275987  32.999444       1
# 7    -33.0   7.0         38.774798       18.132353  32.999896       0
# 8    -33.0   8.0         39.397915       17.840307  32.999849       0
# 9    -33.0   9.0         34.098452       16.531751  32.999863       1
# 10   -33.0  10.0         34.719682       16.423245  32.999609       1
# 11   -33.0  11.0         41.371111       17.512350  32.999751       0
# ...

# %%
x = data.get("X")
y = data.get("Y")
v = data.get("Velocity")
